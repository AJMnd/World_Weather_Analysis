# %% [markdown]
# # Deliverable 1 Retrieve Weather Data

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import random
import numpy as np
import requests 
import pandas as pd
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
cities
# Out:
# ['vaini',
#  'ribeira grande',
#  'cidreira',
#  'troitskoye',
#  'rikitea',
#  'bowen',
#  'sibolga',
#  'almaty',
#  'tasiilaq',
#  'virginia beach',
#  'sitka',
#  'chokurdakh',
#  'new norfolk',
#  'mataura',
#  'ilulissat',
#  'grand river south east',
#  'monte patria',
#  'saleaula',
#  'busselton',
#  'grindavik',
#  'kavieng',
#  'eyl',
#  'coihaique',
#  'vostochnyy',
#  'hithadhoo',
#  'jamestown',
#  'touros',
#  'carnarvon',
#  'taoudenni',
#  'amderma',
#  'marawi',
#  'vangaindrano',
#  'kloulklubed',
#  'ordzhonikidze',
#  'ust-kuyga',
#  'chimbote',
#  'torbay',
#  'khatanga',
#  'svetlogorsk',
#  'atuona',
#  'butaritari',
#  'hermanus',
#  'cape town',
#  'castro',
#  'kaitangata',
#  'sadovoye',
#  'saint george',
#  'punta arenas',
#  'okhotsk',
#  'hilo',
#  'yellowknife',
#  'georgetown',
#  'ivanava',
#  'charters towers',
#  'lumut',
#  'waitati',
#  'mar del plata',
#  'arraial do cabo',
#  'letka',
#  'illoqqortoormiut',
#  'havelock',
#  'pevek',
#  'bluff',
#  'rungata',
#  'lebu',
#  'ilo',
#  'togur',
#  'umm lajj',
#  'opotiki',
#  'axim',
#  'chernyshkovskiy',
#  'labytnangi',
#  'taolanaro',
#  'belmonte',
#  'norman wells',
#  'avarua',
#  'bandarbeyla',
#  'kouango',
#  'zabol',
#  'sioux lookout',
#  'andra',
#  'kolyshley',
#  'severo-kurilsk',
#  'prieska',
#  'ushuaia',
#  'samusu',
#  'hirara',
#  'formosa',
#  'manado',
#  'kapaa',
#  'laiyang',
#  'barentsburg',
#  'boma',
#  'dolbeau',
#  'belushya guba',
#  'qaanaaq',
#  'san patricio',
#  'tsihombe',
#  'port alfred',
#  'jumla',
#  'mildura',
#  'matara',
#  'glendive',
#  'ballina',
#  'ancud',
#  'san andres',
#  'albany',
#  'puerto ayora',
#  'san joaquin',
#  'cap-aux-meules',
#  'coquimbo',
#  'alyangula',
#  'corinto',
#  'kaeo',
#  'hobart',
#  'chingirlau',
#  'tilichiki',
#  'isangel',
#  'baracoa',
#  'chichimila',
#  'lewistown',
#  'kendari',
#  'saint-philippe',
#  'cabo san lucas',
#  'krasnovishersk',
#  'launceston',
#  'aflu',
#  'necochea',
#  'barawe',
#  'saskylakh',
#  'moroni',
#  'kamenskoye',
#  'neryungri',
#  'tuktoyaktuk',
#  'nabire',
#  'lamu',
#  'nikolskoye',
#  'phan thiet',
#  'codrington',
#  'cherskiy',
#  'clyde river',
#  'spornoye',
#  'airai',
#  'datong',
#  'jermuk',
#  'thompson',
#  'muzhi',
#  'kodiak',
#  'falun',
#  'satis',
#  'mae ramat',
#  'plettenberg bay',
#  'merauke',
#  'opaka',
#  'najran',
#  'east london',
#  'longyearbyen',
#  'monrovia',
#  'tall kayf',
#  'alotau',
#  'provideniya',
#  'orchard homes',
#  'matane',
#  'santa isabel do rio negro',
#  'attawapiskat',
#  'waycross',
#  'souillac',
#  'shurugwi',
#  'dunedin',
#  'aleksandrovsk-sakhalinskiy',
#  'saldanha',
#  'mercedes',
#  'tuatapere',
#  'upernavik',
#  'ola',
#  'mora',
#  'margate',
#  'hillsborough',
#  'namibe',
#  'rocha',
#  'tuban',
#  'lagoa',
#  'siocon',
#  'nemuro',
#  'klaksvik',
#  'arica',
#  'half moon bay',
#  'itoman',
#  'mahebourg',
#  'maralal',
#  'shimanovsk',
#  'laguna',
#  'mount gambier',
#  'hailar',
#  'sao joao da barra',
#  'bredasdorp',
#  'yulara',
#  'yar-sale',
#  'vardo',
#  'ejura',
#  'barrow',
#  'segezha',
#  'banganapalle',
#  'maiduguri',
#  'westport',
#  'randazzo',
#  'sale',
#  'san vicente',
#  'bolshaya chernigovka',
#  'goundam',
#  'fortuna',
#  'dingle',
#  'nizhneyansk',
#  'sao filipe',
#  'parry sound',
#  'yagodnoye',
#  'port-gentil',
#  'harlingen',
#  'hermiston',
#  'ostrovnoy',
#  'salalah',
#  'nuristan',
#  'paramonga',
#  'zyryanka',
#  'gazion',
#  'roald',
#  'iquitos',
#  'clarence town',
#  'wanaka',
#  'vredendal',
#  'bonthe',
#  'sept-iles',
#  'esperance',
#  'leningradskiy',
#  'broken hill',
#  'zalantun',
#  'bubaque',
#  'kutum',
#  'healdsburg',
#  'mangai',
#  'mount pleasant',
#  'lompoc',
#  'victoria',
#  'beringovskiy',
#  'high level',
#  'bambous virieux',
#  'port lincoln',
#  'talnakh',
#  'karratha',
#  'dikson',
#  'doha',
#  'khawhai',
#  'shahr-e babak',
#  'mareeba',
#  'cockburn town',
#  'stutterheim',
#  'tabas',
#  'asau',
#  'sorvag',
#  'yomitan',
#  'lavrentiya',
#  'hasaki',
#  'santa maria',
#  'kieta',
#  'ismailia',
#  'chuy',
#  'gornozavodsk',
#  'kasongo-lunda',
#  'namatanai',
#  'port macquarie',
#  'yongchang',
#  'san luis',
#  'teneguiban',
#  'campbellton',
#  'praia da vitoria',
#  'amapa',
#  'bokod',
#  'xining',
#  'komsomolskiy',
#  'finschhafen',
#  'shelburne',
#  'manthani',
#  'bacolod',
#  'poum',
#  'vila velha',
#  'puerto el triunfo',
#  'guara',
#  'ponta do sol',
#  'abu samrah',
#  'nouadhibou',
#  'gornopravdinsk',
#  'yenagoa',
#  'marsa matruh',
#  'fergus falls',
#  'san cristobal',
#  'bardiyah',
#  'bolungarvik',
#  'lasa',
#  'fort-shevchenko',
#  'port elizabeth',
#  'morant bay',
#  'swan river',
#  'cache creek',
#  'kununurra',
#  'acarau',
#  'nome',
#  'katsuura',
#  'cayenne',
#  'guerrero negro',
#  'anadyr',
#  'ijaki',
#  'ocampo',
#  'san martin',
#  'tiksi',
#  'tashara',
#  'davidson',
#  'sola',
#  'ouegoa',
#  'vao',
#  'basud',
#  'mys shmidta',
#  'san clemente',
#  'silver city',
#  'edd',
#  'gimli',
#  'saint-georges',
#  'tateyama',
#  'vila do maio',
#  'jalu',
#  'la ligua',
#  'qasigiannguit',
#  'narsaq',
#  'caravelas',
#  'kushima',
#  'la ronge',
#  'constitucion',
#  'punta alta',
#  'san juan',
#  'oxford',
#  'penzance',
#  'beira',
#  'kahului',
#  'riberalta',
#  'nyurba',
#  'jiayuguan',
#  'stantsiya gorchakovo',
#  'fairbanks',
#  'rabak',
#  'kitakata',
#  'upington',
#  'vila franca do campo',
#  'gurskoye',
#  'iqaluit',
#  'mayo',
#  'gat',
#  'custodia',
#  'palabuhanratu',
#  'gaoua',
#  'phonhong',
#  'mahibadhoo',
#  'saint-augustin',
#  'jurmala',
#  'naron',
#  'tiznit',
#  'kiruna',
#  'petropavlovsk-kamchatskiy',
#  'husavik',
#  'atar',
#  'rafaela',
#  'catamarca',
#  'saurimo',
#  'kaabong',
#  'marienburg',
#  'padang',
#  'kholodnyy',
#  'conceicao do araguaia',
#  'kakonko',
#  'kozhevnikovo',
#  'zarand',
#  'almere',
#  'ust-tsilma',
#  'san quintin',
#  'ambilobe',
#  'paradwip',
#  'lyndon',
#  'stykkisholmur',
#  'jackson',
#  'vreed en hoop',
#  'sanming',
#  'amga',
#  'walvis bay',
#  'las varas',
#  'basco',
#  'bengkulu',
#  'santiago de cao',
#  'peterhead',
#  'jurbarkas',
#  'poplar bluff',
#  'norden',
#  'burgeo',
#  'along',
#  'adre',
#  'mangrol',
#  'camacha',
#  'acapulco',
#  'olinda',
#  'roebourne',
#  'tuy hoa',
#  'griffith',
#  'cuamba',
#  'brae',
#  'juneau',
#  'itaobim',
#  'savannah bight',
#  'yerbogachen',
#  'rudnichnyy',
#  'price',
#  'mandalgovi',
#  'chapais',
#  'texas city',
#  'the valley',
#  'lively',
#  'rundu',
#  'umzimvubu',
#  'sentyabrskiy',
#  'skelleftea',
#  'gamba',
#  'nuevo san juan parangaricutiro',
#  'severobaykalsk',
#  'samalaeulu',
#  'sorrento',
#  'fiumicino',
#  'warqla',
#  'grand gaube',
#  'kristinehamn',
#  'beroroha',
#  'turukhansk',
#  'yuzhou',
#  'hit',
#  'solovetskiy',
#  'elizabeth city',
#  'blagoyevo',
#  'vaitupu',
#  'shahrud',
#  'sorland',
#  'henties bay',
#  'muros',
#  'port hardy',
#  'hami',
#  'strezhevoy',
#  'backa topola',
#  'xinmin',
#  'ukiah',
#  'arawa',
#  'deputatskiy',
#  'ascope',
#  'almaznyy',
#  'mergui',
#  'mudon',
#  'verkhnyaya inta',
#  'batagay-alyta',
#  'kangaatsiaq',
#  'madang',
#  'acajutla',
#  'cervo',
#  'qaqortoq',
#  'sangar',
#  'chutung',
#  'tumannyy',
#  'skorodnoye',
#  'hualmay',
#  'inhambane',
#  'awjilah',
#  'hazorasp',
#  'tomigusuku',
#  'lokosovo',
#  'kamenka',
#  'avera',
#  'xiaoweizhai',
#  'sao felix do xingu',
#  'garowe',
#  'manokwari',
#  'porbandar',
#  'paitan',
#  'maymyo',
#  'bethel',
#  'rio viejo',
#  'makakilo city',
#  'mount isa',
#  'smithers',
#  'kuito',
#  'tari',
#  'lorengau',
#  'matamoros',
#  'olafsvik',
#  'chapada dos guimaraes',
#  'monte cristi',
#  'salinas',
#  'merritt',
#  'usinsk',
#  'chara',
#  'bangangte',
#  'ciras',
#  'tanete',
#  'angoche',
#  'praia',
#  'calvia',
#  'lensk',
#  'olaine',
#  'yarim',
#  'sur',
#  'eureka',
#  'yeniseysk',
#  'shakawe',
#  'ruteng',
#  'itaituba',
#  'houma',
#  'hovd',
#  'naze',
#  'podbelsk',
#  'kalga',
#  'faya',
#  'maniitsoq',
#  'yangambi',
#  'tual',
#  'pyaozerskiy',
#  'yanan',
#  'esfarayen',
#  'honiara',
#  'riyadh',
#  'northport',
#  'hyeres',
#  'yumen',
#  'rahuri',
#  'aksu',
#  'kandrian',
#  'port moresby',
#  'saint anthony',
#  'merritt island',
#  'fomboni',
#  'nioro',
#  'chaman',
#  'qandala',
#  'ibra',
#  'puerto ayacucho',
#  'omboue',
#  'nanortalik',
#  'coahuayana',
#  'sao gabriel da cachoeira',
#  'emerald',
#  'blythe',
#  'skjervoy',
#  'sendafa',
#  'zemetchino',
#  'wasilla',
#  'shimoda',
#  'giyani',
#  'kavaratti',
#  'meyungs',
#  'ayan',
#  'chateauroux',
#  'camopi',
#  'khonuu',
#  'itarema',
#  'mocuba',
#  'noumea',
#  'dera ghazi khan',
#  'pyu',
#  'rawson',
#  'tessalit',
#  'smidovich',
#  'ust-nera',
#  'lata',
#  'tabou',
#  'dzhebariki-khaya',
#  'tacoronte',
#  'san-pedro',
#  'alofi',
#  'sangmelima',
#  'korhogo',
#  'kuching',
#  'khandbari',
#  'flinders',
#  'buin',
#  'bathsheba',
#  'port blair',
#  'galle',
#  'tunceli',
#  'guarapari',
#  'aklavik',
#  'sarahan',
#  'shahr-e kord',
#  'troitsko-pechorsk',
#  'lolua',
#  'durango',
#  'fort nelson',
#  'porto nacional',
#  'bhandara',
#  'kruisfontein',
#  'macae',
#  'gushikawa',
#  'nantucket',
#  'morogoro',
#  'santa rosa',
#  'itapira',
#  'ambunti',
#  'kodinsk',
#  'dawlatabad',
#  'niamey',
#  'kungurtug',
#  'guhagar',
#  'paamiut',
#  'melilla',
#  'quelimane',
#  'oituz',
#  'ustyuzhna',
#  'makokou',
#  'antofagasta',
#  'pemangkat',
#  'aksha',
#  'panama city',
#  'pasighat',
#  'tutoia',
#  'santiago del estero',
#  'ghanzi',
#  'aasiaat',
#  'longkou',
#  'tuggurt',
#  'belaya gora',
#  'kuche',
#  'belyy yar',
#  'hamilton',
#  'louisbourg',
#  'soe',
#  'beaverlodge',
#  'dakar',
#  'la malbaie',
#  'cukai',
#  'tawau',
#  'galesong',
#  'jati',
#  'ust-bolsheretsk',
#  'chumikan',
#  'bandar-e lengeh',
#  'hambantota',
#  'kumluca',
#  'jaguarao',
#  'tolaga bay',
#  'kharp',
#  'ixtapa',
#  'taltal',
#  'college',
#  'felidhoo',
#  'calvinia',
#  'ozernovskiy',
#  'nuuk',
#  'rio grande',
#  'pascagoula',
#  'renigunta',
#  'urusha',
#  'kenai',
#  'toamasina',
#  'presidencia roque saenz pena',
#  'owase',
#  'atambua',
#  'samarai',
#  'moshi',
#  'mikhaylovka',
#  'mrirt',
#  'zhangjiakou',
#  'san rafael',
#  'russell',
#  'chilca',
#  'rio gallegos',
#  'cap malheureux',
#  'kathu',
#  'atasu',
#  'lumphat',
#  'konevo',
#  'cortez',
#  'yuancheng',
#  'coronado',
#  'fatehpur',
#  'chitral',
#  'hay river',
#  'apatlaco',
#  'aden',
#  'kismayo',
#  'pinto',
#  'pamanukan',
#  'alveringem',
#  'havoysund',
#  'geraldton',
#  'doctor pedro p. pena',
#  'edea',
#  'xihe',
#  'sroda wielkopolska',
#  'khash',
#  'gander',
#  'puerto madryn',
#  'khowst',
#  'oxapampa',
#  'christiansfeld',
#  'lexington',
#  'palmer',
#  'bilibino',
#  'nakamura',
#  'tabukiniberu',
#  'yambio',
#  'gravdal',
#  'kirensk',
#  'ranong',
#  'qui nhon',
#  'havre-saint-pierre',
#  'san jose',
#  'srednekolymsk',
#  'kelowna',
#  'picui',
#  'dovbysh',
#  'pisco',
#  'kantang',
#  'ostersund',
#  'haines junction',
#  'tena',
#  'faanui',
#  'luau',
#  'menongue',
#  'borlange',
#  'neuquen',
#  'wajima',
#  'la victoria',
#  'kupang',
#  'ruatoria',
#  'tres arroyos',
#  'loudi',
#  'aksarka',
#  'vakhrushev',
#  'pozo colorado',
#  'kemi',
#  'larsnes',
#  'cartagena',
#  'carballo',
#  'mitchell',
#  'kjollefjord',
#  'arroyo']

# %%
import requests
from config import weather_api_key

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        print(city_weather)
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 84.36, 'feels_like': 96.64, 'temp_min': 84.36, 'temp_max': 84.36, 'pressure': 1011, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 110}, 'clouds': {'all': 40}, 'dt': 1648421180, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1648489619, 'sunset': 1648532658}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 2 of Set 1 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.15, 'feels_like': 59.86, 'temp_min': 60.15, 'temp_max': 60.15, 'pressure': 1019, 'humidity': 85, 'sea_level': 1019, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 16.98, 'deg': 56, 'gust': 17.2}, 'clouds': {'all': 100}, 'dt': 1648421357, 'sys': {'country': 'PT', 'sunrise': 1648367251, 'sunset': 1648411959}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 3 of Set 1 | cidreira
# {'coord': {'lon': -50.2056, 'lat': -30.1811}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.31, 'feels_like': 69.71, 'temp_min': 69.31, 'temp_max': 69.31, 'pressure': 1016, 'humidity': 80, 'sea_level': 1016, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 7.52, 'deg': 59, 'gust': 13.22}, 'clouds': {'all': 0}, 'dt': 1648421426, 'sys': {'country': 'BR', 'sunrise': 1648373302, 'sunset': 1648416229}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# Processing Record 4 of Set 1 | troitskoye
# {'coord': {'lon': 84.6757, 'lat': 52.9821}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 30.34, 'feels_like': 26.74, 'temp_min': 30.34, 'temp_max': 30.34, 'pressure': 1014, 'humidity': 99, 'sea_level': 1014, 'grnd_level': 987}, 'visibility': 132, 'wind': {'speed': 3.51, 'deg': 119, 'gust': 8.34}, 'snow': {'1h': 0.63}, 'clouds': {'all': 100}, 'dt': 1648421427, 'sys': {'country': 'RU', 'sunrise': 1648425933, 'sunset': 1648471631}, 'timezone': 25200, 'id': 1489209, 'name': 'Troitskoye', 'cod': 200}
# Processing Record 5 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.14, 'feels_like': 79.14, 'temp_min': 79.14, 'temp_max': 79.14, 'pressure': 1015, 'humidity': 66, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 9.44, 'deg': 84, 'gust': 9.4}, 'clouds': {'all': 14}, 'dt': 1648421428, 'sys': {'country': 'PF', 'sunrise': 1648393567, 'sunset': 1648436642}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 6 of Set 1 | bowen
# {'coord': {'lon': 148.2333, 'lat': -20.0167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.75, 'feels_like': 78.75, 'temp_min': 78.75, 'temp_max': 78.75, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 5.41, 'deg': 202, 'gust': 6.2}, 'clouds': {'all': 6}, 'dt': 1648421429, 'sys': {'country': 'AU', 'sunrise': 1648411965, 'sunset': 1648455098}, 'timezone': 36000, 'id': 2174444, 'name': 'Bowen', 'cod': 200}
# Processing Record 7 of Set 1 | sibolga
# {'coord': {'lon': 98.7792, 'lat': 1.7427}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.32, 'feels_like': 72.3, 'temp_min': 72.32, 'temp_max': 72.32, 'pressure': 1011, 'humidity': 65, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 4.41, 'deg': 50, 'gust': 3.6}, 'clouds': {'all': 5}, 'dt': 1648421429, 'sys': {'country': 'ID', 'sunrise': 1648423577, 'sunset': 1648467218}, 'timezone': 25200, 'id': 1213855, 'name': 'Sibolga', 'cod': 200}
# Processing Record 8 of Set 1 | almaty
# {'coord': {'lon': 76.95, 'lat': 43.25}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 39.11, 'feels_like': 35.87, 'temp_min': 39.11, 'temp_max': 39.11, 'pressure': 1020, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 130}, 'clouds': {'all': 75}, 'dt': 1648421361, 'sys': {'type': 1, 'id': 8818, 'country': 'KZ', 'sunrise': 1648428109, 'sunset': 1648473162}, 'timezone': 21600, 'id': 1526384, 'name': 'Almaty', 'cod': 200}
# Processing Record 9 of Set 1 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 20.79, 'feels_like': 8.38, 'temp_min': 20.79, 'temp_max': 20.79, 'pressure': 1027, 'humidity': 78, 'sea_level': 1027, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 12.55, 'deg': 49, 'gust': 22.24}, 'clouds': {'all': 100}, 'dt': 1648421431, 'sys': {'country': 'GL', 'sunrise': 1648368274, 'sunset': 1648415225}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 10 of Set 1 | virginia beach
# {'coord': {'lon': -75.978, 'lat': 36.8529}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.57, 'feels_like': 48.16, 'temp_min': 50, 'temp_max': 54.05, 'pressure': 1009, 'humidity': 37}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 220, 'gust': 8.01}, 'clouds': {'all': 79}, 'dt': 1648421355, 'sys': {'type': 2, 'id': 2016102, 'country': 'US', 'sunrise': 1648378621, 'sunset': 1648423278}, 'timezone': -14400, 'id': 4791259, 'name': 'Virginia Beach', 'cod': 200}
# Processing Record 11 of Set 1 | sitka
# {'coord': {'lon': -135.33, 'lat': 57.0531}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 44.49, 'feels_like': 43, 'temp_min': 44.49, 'temp_max': 44.49, 'pressure': 1015, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1648421432, 'sys': {'type': 1, 'id': 7795, 'country': 'US', 'sunrise': 1648392212, 'sunset': 1648438169}, 'timezone': -28800, 'id': 5557293, 'name': 'Sitka', 'cod': 200}
# Processing Record 12 of Set 1 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -7.58, 'feels_like': -19.86, 'temp_min': -7.58, 'temp_max': -7.58, 'pressure': 1011, 'humidity': 97, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 5.28, 'deg': 177, 'gust': 7.02}, 'clouds': {'all': 85}, 'dt': 1648421321, 'sys': {'country': 'RU', 'sunrise': 1648409473, 'sunset': 1648457742}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 13 of Set 1 | new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 61.99, 'feels_like': 60.71, 'temp_min': 60.3, 'temp_max': 63.91, 'pressure': 1013, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 2.26, 'deg': 278, 'gust': 3.49}, 'rain': {'1h': 0.35}, 'clouds': {'all': 93}, 'dt': 1648421433, 'sys': {'type': 2, 'id': 2031307, 'country': 'AU', 'sunrise': 1648412566, 'sunset': 1648455061}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 14 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 66.81, 'feels_like': 65.82, 'temp_min': 66.81, 'temp_max': 66.81, 'pressure': 1021, 'humidity': 56, 'sea_level': 1021, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.62, 'deg': 45, 'gust': 5.41}, 'clouds': {'all': 3}, 'dt': 1648421433, 'sys': {'country': 'NZ', 'sunrise': 1648407390, 'sunset': 1648449772}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 15 of Set 1 | ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 20.07, 'feels_like': 9.48, 'temp_min': 20.07, 'temp_max': 20.07, 'pressure': 1015, 'humidity': 68, 'sea_level': 1015, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 74, 'gust': 8.61}, 'clouds': {'all': 65}, 'dt': 1648421434, 'sys': {'country': 'GL', 'sunrise': 1648371142, 'sunset': 1648418818}, 'timezone': -7200, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# Processing Record 16 of Set 1 | grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 17 of Set 1 | monte patria
# {'coord': {'lon': -70.9467, 'lat': -30.6919}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 76.73, 'feels_like': 75.79, 'temp_min': 76.73, 'temp_max': 76.73, 'pressure': 1013, 'humidity': 36, 'sea_level': 1013, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 4.79, 'deg': 277, 'gust': 4.85}, 'clouds': {'all': 48}, 'dt': 1648421153, 'sys': {'country': 'CL', 'sunrise': 1648378288, 'sunset': 1648421196}, 'timezone': -10800, 'id': 3879429, 'name': 'Monte Patria', 'cod': 200}
# Processing Record 18 of Set 1 | saleaula
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 58.42, 'feels_like': 57.22, 'temp_min': 58.42, 'temp_max': 58.42, 'pressure': 1018, 'humidity': 69, 'sea_level': 1018, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 14.41, 'deg': 121, 'gust': 27.16}, 'clouds': {'all': 0}, 'dt': 1648421436, 'sys': {'country': 'AU', 'sunrise': 1648420041, 'sunset': 1648462811}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 20 of Set 1 | grindavik
# {'coord': {'lon': -22.4338, 'lat': 63.8424}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 39.67, 'feels_like': 31.8, 'temp_min': 39.67, 'temp_max': 40.95, 'pressure': 1020, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 70}, 'clouds': {'all': 100}, 'dt': 1648421436, 'sys': {'type': 1, 'id': 90, 'country': 'IS', 'sunrise': 1648364773, 'sunset': 1648411430}, 'timezone': 0, 'id': 3416888, 'name': 'Grindavik', 'cod': 200}
# Processing Record 21 of Set 1 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.66, 'feels_like': 90.05, 'temp_min': 83.66, 'temp_max': 83.66, 'pressure': 1010, 'humidity': 71, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 8.63, 'deg': 21, 'gust': 8.63}, 'clouds': {'all': 82}, 'dt': 1648421437, 'sys': {'country': 'PG', 'sunrise': 1648411147, 'sunset': 1648454686}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 22 of Set 1 | eyl
# {'coord': {'lon': 49.8164, 'lat': 7.9803}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.51, 'feels_like': 76.19, 'temp_min': 75.51, 'temp_max': 75.51, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.89, 'deg': 23, 'gust': 16.28}, 'clouds': {'all': 59}, 'dt': 1648421438, 'sys': {'country': 'SO', 'sunrise': 1648435247, 'sunset': 1648479046}, 'timezone': 10800, 'id': 60019, 'name': 'Eyl', 'cod': 200}
# Processing Record 23 of Set 1 | coihaique
# {'coord': {'lon': -72.0662, 'lat': -45.5752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 48.15, 'feels_like': 45, 'temp_min': 48.15, 'temp_max': 48.81, 'pressure': 1004, 'humidity': 93}, 'visibility': 9000, 'wind': {'speed': 6.91, 'deg': 40}, 'clouds': {'all': 100}, 'dt': 1648421289, 'sys': {'type': 1, 'id': 8491, 'country': 'CL', 'sunrise': 1648378776, 'sunset': 1648421245}, 'timezone': -10800, 'id': 3894426, 'name': 'Coyhaique', 'cod': 200}
# Processing Record 24 of Set 1 | vostochnyy
# {'coord': {'lon': 37.8667, 'lat': 55.8167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 21.79, 'feels_like': 9.82, 'temp_min': 21.18, 'temp_max': 22.98, 'pressure': 1014, 'humidity': 79, 'sea_level': 1014, 'grnd_level': 992}, 'visibility': 10000, 'wind': {'speed': 12.24, 'deg': 310, 'gust': 22.53}, 'clouds': {'all': 99}, 'dt': 1648421439, 'sys': {'type': 2, 'id': 47754, 'country': 'RU', 'sunrise': 1648437021, 'sunset': 1648483006}, 'timezone': 10800, 'id': 471501, 'name': 'Vostochnyy', 'cod': 200}
# Processing Record 25 of Set 1 | hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 81.63, 'feels_like': 84.78, 'temp_min': 81.63, 'temp_max': 81.63, 'pressure': 1010, 'humidity': 65, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 39, 'gust': 6.2}, 'clouds': {'all': 6}, 'dt': 1648421439, 'sys': {'country': 'MV', 'sunrise': 1648429771, 'sunset': 1648473356}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 26 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 19.47, 'feels_like': 6.87, 'temp_min': 18.95, 'temp_max': 20.71, 'pressure': 1012, 'humidity': 61}, 'visibility': 2816, 'wind': {'speed': 18.41, 'deg': 310, 'gust': 26.46}, 'clouds': {'all': 100}, 'dt': 1648421370, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1648379284, 'sunset': 1648424178}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 27 of Set 1 | touros
# {'coord': {'lon': -35.4608, 'lat': -5.1989}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 80.1, 'feels_like': 84.87, 'temp_min': 80.1, 'temp_max': 80.1, 'pressure': 1012, 'humidity': 83, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 118, 'gust': 17.34}, 'clouds': {'all': 50}, 'dt': 1648421440, 'sys': {'country': 'BR', 'sunrise': 1648369484, 'sunset': 1648412970}, 'timezone': -10800, 'id': 3386213, 'name': 'Touros', 'cod': 200}
# Processing Record 28 of Set 1 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 66.27, 'feels_like': 66.74, 'temp_min': 66.27, 'temp_max': 66.27, 'pressure': 1007, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 30}, 'clouds': {'all': 2}, 'dt': 1648421189, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1648420330, 'sunset': 1648463337}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 29 of Set 1 | taoudenni
# {'coord': {'lon': -3.9836, 'lat': 22.6783}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 87.28, 'feels_like': 84.43, 'temp_min': 87.28, 'temp_max': 87.28, 'pressure': 1014, 'humidity': 26, 'sea_level': 1014, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 5.21, 'deg': 144, 'gust': 6.53}, 'clouds': {'all': 23}, 'dt': 1648421441, 'sys': {'country': 'ML', 'sunrise': 1648361599, 'sunset': 1648405750}, 'timezone': 0, 'id': 2450173, 'name': 'Taoudenni', 'cod': 200}
# Processing Record 30 of Set 1 | amderma
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 31 of Set 1 | marawi
# {'coord': {'lon': 124.2928, 'lat': 7.9986}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 70.3, 'feels_like': 71.22, 'temp_min': 70.3, 'temp_max': 70.3, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 932}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 103, 'gust': 2.48}, 'clouds': {'all': 40}, 'dt': 1648421268, 'sys': {'country': 'PH', 'sunrise': 1648417379, 'sunset': 1648461173}, 'timezone': 28800, 'id': 1701054, 'name': 'Marawi', 'cod': 200}
# Processing Record 32 of Set 1 | vangaindrano
# {'coord': {'lon': 47.6, 'lat': -23.35}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 73.78, 'feels_like': 75.33, 'temp_min': 73.78, 'temp_max': 73.78, 'pressure': 1012, 'humidity': 95, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 4.45, 'deg': 213, 'gust': 7.54}, 'rain': {'1h': 0.77}, 'clouds': {'all': 96}, 'dt': 1648421443, 'sys': {'country': 'MG', 'sunrise': 1648436163, 'sunset': 1648479193}, 'timezone': 10800, 'id': 1054329, 'name': 'Vangaindrano', 'cod': 200}
# Processing Record 33 of Set 1 | kloulklubed
# {'coord': {'lon': 134.2556, 'lat': 7.0419}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.96, 'feels_like': 90.59, 'temp_min': 82.96, 'temp_max': 82.96, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 19.66, 'deg': 66, 'gust': 21.12}, 'clouds': {'all': 92}, 'dt': 1648421443, 'sys': {'country': 'PW', 'sunrise': 1648415001, 'sunset': 1648458770}, 'timezone': 32400, 'id': 7671223, 'name': 'Kloulklubed', 'cod': 200}
# Processing Record 34 of Set 1 | ordzhonikidze
# {'coord': {'lon': 61.7408, 'lat': 52.4411}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 24.04, 'feels_like': 11.73, 'temp_min': 24.04, 'temp_max': 24.04, 'pressure': 1009, 'humidity': 92, 'sea_level': 1009, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 14.2, 'deg': 189, 'gust': 33.64}, 'clouds': {'all': 27}, 'dt': 1648421444, 'sys': {'country': 'KZ', 'sunrise': 1648431450, 'sunset': 1648477120}, 'timezone': 21600, 'id': 1520381, 'name': 'Ordzhonīkīdze', 'cod': 200}
# Processing Record 35 of Set 1 | ust-kuyga
# {'coord': {'lon': 135.6, 'lat': 70.0167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -2.92, 'feels_like': -15.52, 'temp_min': -2.92, 'temp_max': -2.92, 'pressure': 1008, 'humidity': 99, 'sea_level': 1008, 'grnd_level': 999}, 'visibility': 7696, 'wind': {'speed': 7.61, 'deg': 183, 'gust': 9.48}, 'clouds': {'all': 99}, 'dt': 1648421444, 'sys': {'country': 'RU', 'sunrise': 1648412503, 'sunset': 1648460623}, 'timezone': 36000, 'id': 2013921, 'name': 'Ust-Kuyga', 'cod': 200}
# Processing Record 36 of Set 1 | chimbote
# {'coord': {'lon': -78.5783, 'lat': -9.0853}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.91, 'feels_like': 72.37, 'temp_min': 71.91, 'temp_max': 71.91, 'pressure': 1009, 'humidity': 76, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 8.7, 'deg': 186, 'gust': 11.41}, 'clouds': {'all': 85}, 'dt': 1648421375, 'sys': {'country': 'PE', 'sunrise': 1648379874, 'sunset': 1648423273}, 'timezone': -18000, 'id': 3698304, 'name': 'Chimbote', 'cod': 200}
# Processing Record 37 of Set 1 | torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 37.56, 'feels_like': 28.72, 'temp_min': 36.39, 'temp_max': 41.29, 'pressure': 1006, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 190, 'gust': 24.16}, 'clouds': {'all': 100}, 'dt': 1648421268, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1648372780, 'sunset': 1648417963}, 'timezone': -9000, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Processing Record 38 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -21.44, 'feels_like': -34.04, 'temp_min': -21.44, 'temp_max': -21.44, 'pressure': 1012, 'humidity': 100, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 5720, 'wind': {'speed': 4.88, 'deg': 236, 'gust': 4.65}, 'clouds': {'all': 92}, 'dt': 1648421269, 'sys': {'country': 'RU', 'sunrise': 1648420134, 'sunset': 1648468876}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 39 of Set 1 | svetlogorsk
# {'coord': {'lon': 29.7333, 'lat': 52.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 28.53, 'feels_like': 21.02, 'temp_min': 28.53, 'temp_max': 28.53, 'pressure': 1025, 'humidity': 50, 'sea_level': 1025, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 7.4, 'deg': 267, 'gust': 17.74}, 'clouds': {'all': 96}, 'dt': 1648421446, 'sys': {'country': 'BY', 'sunrise': 1648439111, 'sunset': 1648484819}, 'timezone': 10800, 'id': 10722858, 'name': 'Forsytheganj', 'cod': 200}
# Processing Record 40 of Set 1 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.91, 'feels_like': 78.91, 'temp_min': 78.91, 'temp_max': 78.91, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 97, 'gust': 14.27}, 'clouds': {'all': 60}, 'dt': 1648421234, 'sys': {'country': 'PF', 'sunrise': 1648394390, 'sunset': 1648437769}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 41 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.03, 'feels_like': 83.86, 'temp_min': 81.03, 'temp_max': 81.03, 'pressure': 1010, 'humidity': 65, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.67, 'deg': 108, 'gust': 8.57}, 'clouds': {'all': 90}, 'dt': 1648421447, 'sys': {'country': 'KI', 'sunrise': 1648405804, 'sunset': 1648449475}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 42 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.79, 'feels_like': 66.33, 'temp_min': 66.79, 'temp_max': 66.79, 'pressure': 1011, 'humidity': 67, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 3.15, 'deg': 334, 'gust': 3.36}, 'clouds': {'all': 98}, 'dt': 1648421242, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1648443128, 'sunset': 1648485841}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 43 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.35, 'feels_like': 61.43, 'temp_min': 58.1, 'temp_max': 69.12, 'pressure': 1011, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1648421448, 'sys': {'type': 2, 'id': 2030111, 'country': 'ZA', 'sunrise': 1648443315, 'sunset': 1648486043}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 44 of Set 1 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.36, 'feels_like': 64.22, 'temp_min': 64.36, 'temp_max': 64.36, 'pressure': 1015, 'humidity': 79, 'sea_level': 1015, 'grnd_level': 904}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 285, 'gust': 1.03}, 'clouds': {'all': 5}, 'dt': 1648421265, 'sys': {'country': 'BR', 'sunrise': 1648373191, 'sunset': 1648416247}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 45 of Set 1 | kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.98, 'feels_like': 62.13, 'temp_min': 62.98, 'temp_max': 62.98, 'pressure': 1021, 'humidity': 67, 'sea_level': 1021, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 3.04, 'deg': 65, 'gust': 4.5}, 'clouds': {'all': 4}, 'dt': 1648421314, 'sys': {'country': 'NZ', 'sunrise': 1648407156, 'sunset': 1648449535}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 46 of Set 1 | sadovoye
# {'coord': {'lon': 44.5089, 'lat': 47.7764}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 30.92, 'feels_like': 18.91, 'temp_min': 30.92, 'temp_max': 30.92, 'pressure': 1013, 'humidity': 67, 'sea_level': 1013, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 18.84, 'deg': 292, 'gust': 27.2}, 'clouds': {'all': 100}, 'dt': 1648421450, 'sys': {'country': 'RU', 'sunrise': 1648435749, 'sunset': 1648481091}, 'timezone': 10800, 'id': 499535, 'name': 'Sadovoye', 'cod': 200}
# Processing Record 47 of Set 1 | saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.89, 'feels_like': 81.05, 'temp_min': 82.8, 'temp_max': 84.79, 'pressure': 1008, 'humidity': 8}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 220, 'gust': 29.93}, 'clouds': {'all': 0}, 'dt': 1648421255, 'sys': {'type': 2, 'id': 2007591, 'country': 'US', 'sunrise': 1648387632, 'sunset': 1648432314}, 'timezone': -21600, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 48 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.31, 'feels_like': 41.04, 'temp_min': 48.11, 'temp_max': 48.31, 'pressure': 987, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1648421451, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1648378653, 'sunset': 1648420817}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 49 of Set 1 | okhotsk
# {'coord': {'lon': 143.3, 'lat': 59.3833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 4.59, 'feels_like': -8.01, 'temp_min': 4.59, 'temp_max': 4.59, 'pressure': 1005, 'humidity': 75, 'sea_level': 1005, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 17.74, 'deg': 340, 'gust': 25.95}, 'clouds': {'all': 1}, 'dt': 1648421201, 'sys': {'country': 'RU', 'sunrise': 1648411579, 'sunset': 1648457852}, 'timezone': 36000, 'id': 2122605, 'name': 'Okhotsk', 'cod': 200}
# Processing Record 50 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.84, 'feels_like': 78.84, 'temp_min': 76.62, 'temp_max': 80.33, 'pressure': 1016, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1648421188, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1648397884, 'sunset': 1648441981}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 1 of Set 2 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 14.92, 'feels_like': 6.15, 'temp_min': 12.29, 'temp_max': 18.41, 'pressure': 1014, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 20}, 'clouds': {'all': 20}, 'dt': 1648421512, 'sys': {'type': 2, 'id': 2041581, 'country': 'CA', 'sunrise': 1648386878, 'sunset': 1648433437}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 2 of Set 2 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.07, 'feels_like': 78.85, 'temp_min': 76.95, 'temp_max': 80.53, 'pressure': 1009, 'humidity': 93}, 'visibility': 8000, 'wind': {'speed': 3.44, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1648421473, 'sys': {'type': 2, 'id': 49151, 'country': 'MY', 'sunrise': 1648423159, 'sunset': 1648466890}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 3 of Set 2 | ivanava
# {'coord': {'lon': 25.5365, 'lat': 52.1451}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 32.04, 'feels_like': 24.76, 'temp_min': 32.04, 'temp_max': 32.04, 'pressure': 1026, 'humidity': 55, 'sea_level': 1026, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 8.21, 'deg': 225, 'gust': 18.37}, 'clouds': {'all': 82}, 'dt': 1648421513, 'sys': {'country': 'BY', 'sunrise': 1648440137, 'sunset': 1648485808}, 'timezone': 10800, 'id': 627811, 'name': 'Ivanava', 'cod': 200}
# Processing Record 4 of Set 2 | charters towers
# {'coord': {'lon': 146.2667, 'lat': -20.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.88, 'feels_like': 78.48, 'temp_min': 77.88, 'temp_max': 77.88, 'pressure': 1010, 'humidity': 66, 'sea_level': 1010, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 2.17, 'deg': 31, 'gust': 2.28}, 'clouds': {'all': 4}, 'dt': 1648421514, 'sys': {'country': 'AU', 'sunrise': 1648412438, 'sunset': 1648455569}, 'timezone': 36000, 'id': 2171722, 'name': 'Charters Towers', 'cod': 200}
# Processing Record 5 of Set 2 | lumut
# {'coord': {'lon': 100.6298, 'lat': 4.2323}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 77.02, 'feels_like': 78.31, 'temp_min': 77.02, 'temp_max': 77.02, 'pressure': 1009, 'humidity': 83}, 'visibility': 9000, 'wind': {'speed': 2.3, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1648421514, 'sys': {'type': 1, 'id': 9426, 'country': 'MY', 'sunrise': 1648423103, 'sunset': 1648466805}, 'timezone': 28800, 'id': 1735450, 'name': 'Lumut', 'cod': 200}
# Processing Record 6 of Set 2 | waitati
# {'coord': {'lon': 170.5667, 'lat': -45.75}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.8, 'feels_like': 62.55, 'temp_min': 62.8, 'temp_max': 62.8, 'pressure': 1022, 'humidity': 80, 'sea_level': 1022, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 8.9, 'deg': 35, 'gust': 12.15}, 'clouds': {'all': 0}, 'dt': 1648421409, 'sys': {'type': 2, 'id': 75281, 'country': 'NZ', 'sunrise': 1648406973, 'sunset': 1648449372}, 'timezone': 46800, 'id': 2179825, 'name': 'Waitati', 'cod': 200}
# Processing Record 7 of Set 2 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63.88, 'feels_like': 63.21, 'temp_min': 63.88, 'temp_max': 66.22, 'pressure': 1012, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 233, 'gust': 10}, 'clouds': {'all': 0}, 'dt': 1648421515, 'sys': {'type': 2, 'id': 2000296, 'country': 'AR', 'sunrise': 1648375172, 'sunset': 1648417887}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 8 of Set 2 | arraial do cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09n'}, {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 78.66, 'feels_like': 80.4, 'temp_min': 78.66, 'temp_max': 78.66, 'pressure': 1014, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 140}, 'rain': {'1h': 3.65}, 'clouds': {'all': 40}, 'dt': 1648421349, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1648371253, 'sunset': 1648414353}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 9 of Set 2 | letka
# {'coord': {'lon': 49.4232, 'lat': 59.6011}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 14.85, 'feels_like': 2.25, 'temp_min': 14.85, 'temp_max': 14.85, 'pressure': 992, 'humidity': 91, 'sea_level': 992, 'grnd_level': 972}, 'visibility': 655, 'wind': {'speed': 11.12, 'deg': 301, 'gust': 24.09}, 'clouds': {'all': 100}, 'dt': 1648421516, 'sys': {'country': 'RU', 'sunrise': 1648434050, 'sunset': 1648480432}, 'timezone': 10800, 'id': 535639, 'name': 'Letka', 'cod': 200}
# Processing Record 10 of Set 2 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 11 of Set 2 | havelock
# {'coord': {'lon': -76.9013, 'lat': 34.8791}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 60.37, 'feels_like': 57.42, 'temp_min': 58.93, 'temp_max': 60.94, 'pressure': 1010, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 290, 'gust': 24.16}, 'clouds': {'all': 0}, 'dt': 1648421517, 'sys': {'type': 1, 'id': 5098, 'country': 'US', 'sunrise': 1648378882, 'sunset': 1648423460}, 'timezone': -14400, 'id': 4470244, 'name': 'Havelock', 'cod': 200}
# Processing Record 12 of Set 2 | pevek
# {'coord': {'lon': 170.3133, 'lat': 69.7008}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': -11.04, 'feels_like': -23.64, 'temp_min': -11.04, 'temp_max': -11.04, 'pressure': 1019, 'humidity': 95, 'sea_level': 1019, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 7.72, 'deg': 167, 'gust': 10.22}, 'clouds': {'all': 41}, 'dt': 1648421518, 'sys': {'country': 'RU', 'sunrise': 1648404239, 'sunset': 1648452228}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# Processing Record 13 of Set 2 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 58.53, 'feels_like': 57.61, 'temp_min': 58.53, 'temp_max': 58.53, 'pressure': 1021, 'humidity': 75, 'sea_level': 1021, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 1.95, 'deg': 25, 'gust': 3.47}, 'clouds': {'all': 10}, 'dt': 1648421231, 'sys': {'country': 'NZ', 'sunrise': 1648407526, 'sunset': 1648449891}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 14 of Set 2 | rungata
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 15 of Set 2 | lebu
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 55.74, 'feels_like': 54.77, 'temp_min': 55.74, 'temp_max': 55.74, 'pressure': 1018, 'humidity': 80, 'sea_level': 1018, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 10.74, 'deg': 185, 'gust': 18.14}, 'clouds': {'all': 0}, 'dt': 1648421520, 'sys': {'country': 'CL', 'sunrise': 1648379031, 'sunset': 1648421751}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 16 of Set 2 | ilo
# {'coord': {'lon': -71.3375, 'lat': -17.6394}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 70.09, 'feels_like': 70.5, 'temp_min': 70.09, 'temp_max': 70.09, 'pressure': 1012, 'humidity': 79, 'sea_level': 1012, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 7.36, 'deg': 162, 'gust': 8.79}, 'clouds': {'all': 17}, 'dt': 1648421521, 'sys': {'country': 'PE', 'sunrise': 1648378229, 'sunset': 1648421442}, 'timezone': -18000, 'id': 3938415, 'name': 'Ilo', 'cod': 200}
# Processing Record 17 of Set 2 | togur
# {'coord': {'lon': 82.8265, 'lat': 58.3631}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -4.41, 'feels_like': -13.11, 'temp_min': -4.41, 'temp_max': -4.41, 'pressure': 1021, 'humidity': 100, 'sea_level': 1021, 'grnd_level': 1012}, 'visibility': 6664, 'wind': {'speed': 3.56, 'deg': 151, 'gust': 3.47}, 'clouds': {'all': 73}, 'dt': 1648421522, 'sys': {'country': 'RU', 'sunrise': 1648426120, 'sunset': 1648472331}, 'timezone': 25200, 'id': 1489499, 'name': 'Togur', 'cod': 200}
# Processing Record 18 of Set 2 | umm lajj
# {'coord': {'lon': 37.2685, 'lat': 25.0213}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.03, 'feels_like': 76.6, 'temp_min': 78.03, 'temp_max': 78.03, 'pressure': 1013, 'humidity': 23, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 25.81, 'deg': 60, 'gust': 38.01}, 'clouds': {'all': 62}, 'dt': 1648421522, 'sys': {'country': 'SA', 'sunrise': 1648438009, 'sunset': 1648482306}, 'timezone': 10800, 'id': 100926, 'name': 'Umluj', 'cod': 200}
# Processing Record 19 of Set 2 | opotiki
# {'coord': {'lon': 177.2833, 'lat': -38.0833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.38, 'feels_like': 64.33, 'temp_min': 64.38, 'temp_max': 64.38, 'pressure': 1017, 'humidity': 81, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 10.87, 'deg': 182, 'gust': 29.08}, 'clouds': {'all': 100}, 'dt': 1648421409, 'sys': {'type': 2, 'id': 2000325, 'country': 'NZ', 'sunrise': 1648405230, 'sunset': 1648447892}, 'timezone': 46800, 'id': 2208332, 'name': 'Opotiki', 'cod': 200}
# Processing Record 20 of Set 2 | axim
# {'coord': {'lon': -2.2405, 'lat': 4.8699}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.47, 'feels_like': 86.25, 'temp_min': 80.47, 'temp_max': 80.47, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.85, 'deg': 179, 'gust': 12.64}, 'clouds': {'all': 79}, 'dt': 1648421523, 'sys': {'country': 'GH', 'sunrise': 1648361403, 'sunset': 1648405109}, 'timezone': 0, 'id': 2303611, 'name': 'Esim', 'cod': 200}
# Processing Record 21 of Set 2 | chernyshkovskiy
# {'coord': {'lon': 42.2308, 'lat': 48.4219}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 27.55, 'feels_like': 14.95, 'temp_min': 27.55, 'temp_max': 27.55, 'pressure': 1015, 'humidity': 80, 'sea_level': 1015, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 17.74, 'deg': 302, 'gust': 26.02}, 'clouds': {'all': 100}, 'dt': 1648421524, 'sys': {'type': 5, 'id': 50002359, 'country': 'RU', 'sunrise': 1648436274, 'sunset': 1648481659}, 'timezone': 10800, 'id': 568527, 'name': 'Chernyshkovskiy', 'cod': 200}
# Processing Record 22 of Set 2 | labytnangi
# {'coord': {'lon': 66.4183, 'lat': 66.6572}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 17.67, 'feels_like': 6.53, 'temp_min': 17.67, 'temp_max': 17.67, 'pressure': 1001, 'humidity': 96, 'sea_level': 1001, 'grnd_level': 999}, 'visibility': 107, 'wind': {'speed': 9.17, 'deg': 85, 'gust': 18.37}, 'snow': {'1h': 0.86}, 'clouds': {'all': 100}, 'dt': 1648421525, 'sys': {'country': 'RU', 'sunrise': 1648429439, 'sunset': 1648476887}, 'timezone': 18000, 'id': 1500933, 'name': 'Labytnangi', 'cod': 200}
# Processing Record 23 of Set 2 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 24 of Set 2 | belmonte
# {'coord': {'lon': -38.8828, 'lat': -15.8631}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.17, 'feels_like': 79.45, 'temp_min': 78.17, 'temp_max': 78.17, 'pressure': 1014, 'humidity': 80, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 6.13, 'deg': 67, 'gust': 7.4}, 'clouds': {'all': 7}, 'dt': 1648421526, 'sys': {'country': 'BR', 'sunrise': 1648370420, 'sunset': 1648413677}, 'timezone': -10800, 'id': 3470137, 'name': 'Belmonte', 'cod': 200}
# Processing Record 25 of Set 2 | norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 6.84, 'feels_like': -5.76, 'temp_min': 6.84, 'temp_max': 6.84, 'pressure': 1018, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1648421526, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1648389652, 'sunset': 1648436651}, 'timezone': -21600, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 26 of Set 2 | avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.25, 'feels_like': 94.3, 'temp_min': 84.25, 'temp_max': 84.25, 'pressure': 1013, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1648421464, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1648399499, 'sunset': 1648442614}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 27 of Set 2 | bandarbeyla
# {'coord': {'lon': 50.8122, 'lat': 9.4942}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77.56, 'feels_like': 78.35, 'temp_min': 77.56, 'temp_max': 77.56, 'pressure': 1012, 'humidity': 71, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 10.54, 'deg': 24, 'gust': 14.58}, 'clouds': {'all': 4}, 'dt': 1648421354, 'sys': {'country': 'SO', 'sunrise': 1648434988, 'sunset': 1648478827}, 'timezone': 10800, 'id': 64814, 'name': 'Bandarbeyla', 'cod': 200}
# Processing Record 28 of Set 2 | kouango
# {'coord': {'lon': 19.9619, 'lat': 4.9934}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.71, 'feels_like': 75.11, 'temp_min': 76.71, 'temp_max': 76.71, 'pressure': 1008, 'humidity': 22, 'sea_level': 1008, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 197, 'gust': 1.88}, 'clouds': {'all': 76}, 'dt': 1648421528, 'sys': {'country': 'CF', 'sunrise': 1648356075, 'sunset': 1648399783}, 'timezone': 3600, 'id': 2385535, 'name': 'Kouango', 'cod': 200}
# Processing Record 29 of Set 2 | zabol
# {'coord': {'lon': 67.25, 'lat': 32.25}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.87, 'feels_like': 49.95, 'temp_min': 53.87, 'temp_max': 53.87, 'pressure': 1014, 'humidity': 21, 'sea_level': 1014, 'grnd_level': 816}, 'visibility': 10000, 'wind': {'speed': 9.08, 'deg': 209, 'gust': 9.44}, 'clouds': {'all': 0}, 'dt': 1648421528, 'sys': {'country': 'AF', 'sunrise': 1648430688, 'sunset': 1648475238}, 'timezone': 16200, 'id': 1121143, 'name': 'Zabul Province', 'cod': 200}
# Processing Record 30 of Set 2 | sioux lookout
# {'coord': {'lon': -91.917, 'lat': 50.1001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 14.07, 'feels_like': 1.47, 'temp_min': 14.07, 'temp_max': 14.07, 'pressure': 1022, 'humidity': 34}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 300, 'gust': 19.57}, 'clouds': {'all': 0}, 'dt': 1648421529, 'sys': {'type': 1, 'id': 979, 'country': 'CA', 'sunrise': 1648382093, 'sunset': 1648427455}, 'timezone': -18000, 'id': 6148373, 'name': 'Sioux Lookout', 'cod': 200}
# Processing Record 31 of Set 2 | andra
# {'coord': {'lon': 65.8878, 'lat': 62.5147}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 20.32, 'feels_like': 7.72, 'temp_min': 20.32, 'temp_max': 20.32, 'pressure': 1000, 'humidity': 92, 'sea_level': 1000, 'grnd_level': 991}, 'visibility': 3450, 'wind': {'speed': 16.55, 'deg': 142, 'gust': 31.41}, 'clouds': {'all': 100}, 'dt': 1648421529, 'sys': {'country': 'RU', 'sunrise': 1648429916, 'sunset': 1648476665}, 'timezone': 18000, 'id': 1511646, 'name': 'Andra', 'cod': 200}
# Processing Record 32 of Set 2 | kolyshley
# {'coord': {'lon': 44.5367, 'lat': 52.7005}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 22.77, 'feels_like': 10.17, 'temp_min': 22.77, 'temp_max': 22.77, 'pressure': 1005, 'humidity': 92, 'sea_level': 1005, 'grnd_level': 979}, 'visibility': 907, 'wind': {'speed': 16.37, 'deg': 321, 'gust': 26.22}, 'clouds': {'all': 97}, 'dt': 1648421530, 'sys': {'country': 'RU', 'sunrise': 1648435562, 'sunset': 1648481265}, 'timezone': 10800, 'id': 545982, 'name': 'Kolyshley', 'cod': 200}
# Processing Record 33 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 33.26, 'feels_like': 20.66, 'temp_min': 33.26, 'temp_max': 33.26, 'pressure': 981, 'humidity': 90, 'sea_level': 981, 'grnd_level': 981}, 'visibility': 1907, 'wind': {'speed': 25.7, 'deg': 205, 'gust': 37.38}, 'snow': {'1h': 0.23}, 'clouds': {'all': 79}, 'dt': 1648421341, 'sys': {'country': 'RU', 'sunrise': 1648408901, 'sunset': 1648454375}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 34 of Set 2 | prieska
# {'coord': {'lon': 22.7474, 'lat': -29.6641}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 75.06, 'feels_like': 73.87, 'temp_min': 75.06, 'temp_max': 75.06, 'pressure': 1015, 'humidity': 34, 'sea_level': 1015, 'grnd_level': 912}, 'visibility': 10000, 'wind': {'speed': 6.26, 'deg': 358, 'gust': 6.33}, 'clouds': {'all': 28}, 'dt': 1648421531, 'sys': {'country': 'ZA', 'sunrise': 1648442215, 'sunset': 1648485068}, 'timezone': 7200, 'id': 964090, 'name': 'Prieska', 'cod': 200}
# Processing Record 35 of Set 2 | ushuaia
# ...
# Processing Record 18 of Set 15 | picui
# {'coord': {'lon': -36.3469, 'lat': -6.5106}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.3, 'feels_like': 75.52, 'temp_min': 74.3, 'temp_max': 74.3, 'pressure': 1013, 'humidity': 87, 'sea_level': 1013, 'grnd_level': 964}, 'visibility': 10000, 'wind': {'speed': 12.5, 'deg': 106, 'gust': 21.81}, 'rain': {'1h': 1.94}, 'clouds': {'all': 97}, 'dt': 1648422705, 'sys': {'country': 'BR', 'sunrise': 1648369711, 'sunset': 1648413169}, 'timezone': -10800, 'id': 3392145, 'name': 'Picuí', 'cod': 200}
# Processing Record 19 of Set 15 | dovbysh
# {'coord': {'lon': 27.9874, 'lat': 50.3733}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 30.04, 'feels_like': 23.76, 'temp_min': 30.04, 'temp_max': 30.04, 'pressure': 1029, 'humidity': 56, 'sea_level': 1029, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 280, 'gust': 14.03}, 'clouds': {'all': 93}, 'dt': 1648422705, 'sys': {'country': 'UA', 'sunrise': 1648439618, 'sunset': 1648485151}, 'timezone': 10800, 'id': 709665, 'name': 'Dovbysh', 'cod': 200}
# Processing Record 20 of Set 15 | pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 71.65, 'feels_like': 71.94, 'temp_min': 70.02, 'temp_max': 71.65, 'pressure': 1009, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1648422706, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1648379357, 'sunset': 1648422656}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 21 of Set 15 | kantang
# {'coord': {'lon': 99.5156, 'lat': 7.4054}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 76.84, 'feels_like': 78.55, 'temp_min': 76.84, 'temp_max': 76.84, 'pressure': 1010, 'humidity': 92, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.46, 'deg': 55, 'gust': 2.21}, 'clouds': {'all': 6}, 'dt': 1648422707, 'sys': {'country': 'TH', 'sunrise': 1648423331, 'sunset': 1648467112}, 'timezone': 25200, 'id': 1153072, 'name': 'Kantang', 'cod': 200}
# Processing Record 22 of Set 15 | ostersund
# {'coord': {'lon': 14.6357, 'lat': 63.1792}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 36.05, 'feels_like': 26.42, 'temp_min': 36.05, 'temp_max': 36.61, 'pressure': 999, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 260}, 'clouds': {'all': 100}, 'dt': 1648422708, 'sys': {'type': 1, 'id': 1774, 'country': 'SE', 'sunrise': 1648442138, 'sunset': 1648489038}, 'timezone': 7200, 'id': 2685750, 'name': 'Östersund', 'cod': 200}
# Processing Record 23 of Set 15 | haines junction
# {'coord': {'lon': -137.5108, 'lat': 60.7522}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 31.24, 'feels_like': 31.24, 'temp_min': 31.24, 'temp_max': 31.24, 'pressure': 1013, 'humidity': 78, 'sea_level': 1013, 'grnd_level': 940}, 'visibility': 10000, 'wind': {'speed': 1.7, 'deg': 206, 'gust': 4.38}, 'clouds': {'all': 94}, 'dt': 1648422709, 'sys': {'country': 'CA', 'sunrise': 1648392533, 'sunset': 1648438895}, 'timezone': -25200, 'id': 5969025, 'name': 'Haines Junction', 'cod': 200}
# Processing Record 24 of Set 15 | tena
# {'coord': {'lon': -77.8167, 'lat': -0.9833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 70.47, 'feels_like': 71.87, 'temp_min': 70.47, 'temp_max': 70.47, 'pressure': 1013, 'humidity': 99, 'sea_level': 1013, 'grnd_level': 954}, 'visibility': 10000, 'wind': {'speed': 0.83, 'deg': 217, 'gust': 1.16}, 'rain': {'1h': 0.14}, 'clouds': {'all': 100}, 'dt': 1648422710, 'sys': {'country': 'EC', 'sunrise': 1648379602, 'sunset': 1648423179}, 'timezone': -18000, 'id': 3650721, 'name': 'Tena', 'cod': 200}
# Processing Record 25 of Set 15 | faanui
# {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.02, 'feels_like': 86.92, 'temp_min': 82.02, 'temp_max': 82.02, 'pressure': 1012, 'humidity': 72, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 12.77, 'deg': 84, 'gust': 13.71}, 'clouds': {'all': 18}, 'dt': 1648422711, 'sys': {'country': 'PF', 'sunrise': 1648397517, 'sunset': 1648440744}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# Processing Record 26 of Set 15 | luau
# {'coord': {'lon': 22.2247, 'lat': -10.7073}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.42, 'feels_like': 65.12, 'temp_min': 64.42, 'temp_max': 64.42, 'pressure': 1013, 'humidity': 97, 'sea_level': 1013, 'grnd_level': 891}, 'visibility': 10000, 'wind': {'speed': 2.55, 'deg': 175, 'gust': 2.75}, 'clouds': {'all': 84}, 'dt': 1648422712, 'sys': {'country': 'AO', 'sunrise': 1648442098, 'sunset': 1648485436}, 'timezone': 3600, 'id': 876177, 'name': 'Luau', 'cod': 200}
# Processing Record 27 of Set 15 | menongue
# {'coord': {'lon': 17.691, 'lat': -14.6585}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.32, 'feels_like': 65.82, 'temp_min': 65.32, 'temp_max': 65.32, 'pressure': 1015, 'humidity': 91, 'sea_level': 1015, 'grnd_level': 868}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 45, 'gust': 2.51}, 'clouds': {'all': 96}, 'dt': 1648422712, 'sys': {'country': 'AO', 'sunrise': 1648443234, 'sunset': 1648486476}, 'timezone': 3600, 'id': 3347353, 'name': 'Menongue', 'cod': 200}
# Processing Record 28 of Set 15 | borlange
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 15 | neuquen
# {'coord': {'lon': -68.0591, 'lat': -38.9516}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.69, 'feels_like': 69.19, 'temp_min': 69.69, 'temp_max': 69.69, 'pressure': 1011, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1648422713, 'sys': {'type': 1, 'id': 8310, 'country': 'AR', 'sunrise': 1648377707, 'sunset': 1648420391}, 'timezone': -10800, 'id': 3843123, 'name': 'Neuquén', 'cod': 200}
# Processing Record 30 of Set 15 | wajima
# {'coord': {'lon': 136.9, 'lat': 37.4}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.11, 'feels_like': 40.3, 'temp_min': 46.11, 'temp_max': 46.11, 'pressure': 1024, 'humidity': 44, 'sea_level': 1024, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 12.73, 'deg': 308, 'gust': 13.73}, 'clouds': {'all': 96}, 'dt': 1648422714, 'sys': {'country': 'JP', 'sunrise': 1648413882, 'sunset': 1648458620}, 'timezone': 32400, 'id': 1848976, 'name': 'Wajima', 'cod': 200}
# Processing Record 31 of Set 15 | la victoria
# {'coord': {'lon': -67.3302, 'lat': 10.2184}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.92, 'feels_like': 79.92, 'temp_min': 79.92, 'temp_max': 79.92, 'pressure': 1011, 'humidity': 60, 'sea_level': 1011, 'grnd_level': 947}, 'visibility': 10000, 'wind': {'speed': 4.03, 'deg': 55, 'gust': 7.65}, 'clouds': {'all': 99}, 'dt': 1648422715, 'sys': {'country': 'VE', 'sunrise': 1648376957, 'sunset': 1648420792}, 'timezone': -14400, 'id': 3634922, 'name': 'La Victoria', 'cod': 200}
# Processing Record 32 of Set 15 | kupang
# {'coord': {'lon': 123.5833, 'lat': -10.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.76, 'feels_like': 78.76, 'temp_min': 78.76, 'temp_max': 78.76, 'pressure': 1010, 'humidity': 86, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 43, 'gust': 2.68}, 'clouds': {'all': 89}, 'dt': 1648422715, 'sys': {'country': 'ID', 'sunrise': 1648417766, 'sunset': 1648461127}, 'timezone': 28800, 'id': 2057087, 'name': 'Kupang', 'cod': 200}
# Processing Record 33 of Set 15 | ruatoria
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 34 of Set 15 | tres arroyos
# {'coord': {'lon': -60.2798, 'lat': -38.3739}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.14, 'feels_like': 56.95, 'temp_min': 58.14, 'temp_max': 58.14, 'pressure': 1014, 'humidity': 70, 'sea_level': 1014, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 6.53, 'deg': 97, 'gust': 6.78}, 'clouds': {'all': 0}, 'dt': 1648422716, 'sys': {'country': 'AR', 'sunrise': 1648375831, 'sunset': 1648418534}, 'timezone': -10800, 'id': 3833859, 'name': 'Tres Arroyos', 'cod': 200}
# Processing Record 35 of Set 15 | loudi
# {'coord': {'lon': 111.9944, 'lat': 27.7344}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 49.8, 'feels_like': 49.8, 'temp_min': 49.8, 'temp_max': 49.8, 'pressure': 1022, 'humidity': 90, 'sea_level': 1022, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 1.43, 'deg': 210, 'gust': 1.36}, 'clouds': {'all': 39}, 'dt': 1648422717, 'sys': {'country': 'CN', 'sunrise': 1648420042, 'sunset': 1648464412}, 'timezone': 28800, 'id': 1802238, 'name': 'Loudi', 'cod': 200}
# Processing Record 36 of Set 15 | aksarka
# {'coord': {'lon': 67.7975, 'lat': 66.5606}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 17.62, 'feels_like': 5.02, 'temp_min': 17.62, 'temp_max': 17.62, 'pressure': 1002, 'humidity': 93, 'sea_level': 1002, 'grnd_level': 999}, 'visibility': 3871, 'wind': {'speed': 14, 'deg': 136, 'gust': 26.04}, 'snow': {'1h': 0.17}, 'clouds': {'all': 100}, 'dt': 1648422717, 'sys': {'country': 'RU', 'sunrise': 1648429118, 'sunset': 1648476545}, 'timezone': 18000, 'id': 1512019, 'name': 'Aksarka', 'cod': 200}
# Processing Record 37 of Set 15 | vakhrushev
# {'coord': {'lon': 142.9667, 'lat': 48.9833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 27.46, 'feels_like': 14.86, 'temp_min': 27.46, 'temp_max': 27.46, 'pressure': 1000, 'humidity': 71, 'sea_level': 1000, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 18.79, 'deg': 296, 'gust': 25.86}, 'clouds': {'all': 100}, 'dt': 1648422718, 'sys': {'country': 'RU', 'sunrise': 1648412113, 'sunset': 1648457477}, 'timezone': 39600, 'id': 2119964, 'name': 'Vakhrushev', 'cod': 200}
# Processing Record 38 of Set 15 | pozo colorado
# {'coord': {'lon': -58.7972, 'lat': -23.4923}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.04, 'feels_like': 74.41, 'temp_min': 75.04, 'temp_max': 75.04, 'pressure': 1012, 'humidity': 46, 'sea_level': 1012, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 98, 'gust': 4.7}, 'clouds': {'all': 0}, 'dt': 1648422719, 'sys': {'country': 'PY', 'sunrise': 1648375285, 'sunset': 1648418369}, 'timezone': -14400, 'id': 3437443, 'name': 'Pozo Colorado', 'cod': 200}
# Processing Record 39 of Set 15 | kemi
# {'coord': {'lon': 24.8228, 'lat': 65.8596}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 20.97, 'feels_like': 8.37, 'temp_min': 20.97, 'temp_max': 20.97, 'pressure': 997, 'humidity': 86}, 'visibility': 2600, 'wind': {'speed': 13.8, 'deg': 100}, 'snow': {'1h': 0.21}, 'clouds': {'all': 100}, 'dt': 1648422719, 'sys': {'type': 1, 'id': 1341, 'country': 'FI', 'sunrise': 1648439472, 'sunset': 1648486816}, 'timezone': 10800, 'id': 653257, 'name': 'Keminmaa', 'cod': 200}
# Processing Record 40 of Set 15 | larsnes
# {'coord': {'lon': 5.5773, 'lat': 62.2028}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 45.3, 'feels_like': 36.99, 'temp_min': 43.81, 'temp_max': 48.61, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 22.26, 'deg': 260, 'gust': 31.61}, 'clouds': {'all': 100}, 'dt': 1648422720, 'sys': {'type': 2, 'id': 2006415, 'country': 'NO', 'sunrise': 1648444379, 'sunset': 1648491144}, 'timezone': 7200, 'id': 3148133, 'name': 'Larsnes', 'cod': 200}
# Processing Record 41 of Set 15 | cartagena
# {'coord': {'lon': -75.5144, 'lat': 10.3997}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.02, 'feels_like': 87.39, 'temp_min': 82.02, 'temp_max': 82.02, 'pressure': 1008, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1648422631, 'sys': {'type': 1, 'id': 8588, 'country': 'CO', 'sunrise': 1648378918, 'sunset': 1648422758}, 'timezone': -18000, 'id': 3687238, 'name': 'Cartagena', 'cod': 200}
# Processing Record 42 of Set 15 | carballo
# {'coord': {'lon': -8.691, 'lat': 43.213}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.67, 'feels_like': 54.7, 'temp_min': 52.75, 'temp_max': 59.9, 'pressure': 1021, 'humidity': 80, 'sea_level': 1021, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 96, 'gust': 1.74}, 'clouds': {'all': 100}, 'dt': 1648422721, 'sys': {'type': 2, 'id': 2045923, 'country': 'ES', 'sunrise': 1648448639, 'sunset': 1648493732}, 'timezone': 7200, 'id': 3126369, 'name': 'Carballo', 'cod': 200}
# Processing Record 43 of Set 15 | mitchell
# {'coord': {'lon': -98.0298, 'lat': 43.7094}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 40.26, 'feels_like': 32.94, 'temp_min': 38.73, 'temp_max': 41.11, 'pressure': 1023, 'humidity': 20}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 140}, 'clouds': {'all': 0}, 'dt': 1648422722, 'sys': {'type': 2, 'id': 2039694, 'country': 'US', 'sunrise': 1648383748, 'sunset': 1648428733}, 'timezone': -18000, 'id': 5229794, 'name': 'Mitchell', 'cod': 200}
# Processing Record 44 of Set 15 | kjollefjord
# {'coord': {'lon': 27.3465, 'lat': 70.9457}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 15.62, 'feels_like': 5.83, 'temp_min': 15.62, 'temp_max': 19.45, 'pressure': 1005, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 150}, 'snow': {'1h': 0.21}, 'clouds': {'all': 40}, 'dt': 1648422722, 'sys': {'type': 1, 'id': 1633, 'country': 'NO', 'sunrise': 1648438267, 'sunset': 1648486809}, 'timezone': 7200, 'id': 779261, 'name': 'Kjøllefjord', 'cod': 200}
# Processing Record 45 of Set 15 | arroyo
# {'coord': {'lon': -4.7969, 'lat': 41.6096}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.06, 'feels_like': 46.18, 'temp_min': 47.14, 'temp_max': 51.6, 'pressure': 1022, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 110}, 'clouds': {'all': 0}, 'dt': 1648422723, 'sys': {'type': 2, 'id': 203198, 'country': 'ES', 'sunrise': 1648447749, 'sunset': 1648492753}, 'timezone': 7200, 'id': 3129371, 'name': 'Arroyo de la Encomienda', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather_data_df = pd.DataFrame(city_data)
city_weather_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Vaini      TO -21.2000 -175.2000     84.36        84
# 1    Ribeira Grande      PT  38.5167  -28.7000     60.15        85
# 2          Cidreira      BR -30.1811  -50.2056     69.31        80
# 3        Troitskoye      RU  52.9821   84.6757     30.34        99
# 4           Rikitea      PF -23.1203 -134.9692     79.14        66
# ..              ...     ...      ...       ...       ...       ...
# 684       Cartagena      CO  10.3997  -75.5144     82.02        74
# 685        Carballo      ES  43.2130   -8.6910     59.90        80
# 686        Mitchell      US  43.7094  -98.0298     41.11        20
# 687     Kjollefjord      NO  70.9457   27.3465     19.45        86
# 688          Arroyo      ES  41.6096   -4.7969     51.60        76
#
#      Cloudiness  Wind Speed       Description
# 0            40        5.75  scattered clouds
# 1           100       16.98   overcast clouds
# 2             0        7.52         clear sky
# 3           100        3.51              snow
# 4            14        9.44        few clouds
# ..          ...         ...               ...
# 684          75       13.80     broken clouds
# 685         100        1.54   overcast clouds
# 686           0       12.66         clear sky
# 687          40        6.91        light snow
# 688           0        4.61         clear sky
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_database.csv"
city_weather_data_df.to_csv(output_data_file, index_label="City_ID")
